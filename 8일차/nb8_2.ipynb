# %%
num= int(input("숫자를 입력하세요"))
print(num*10)
# Out:
# 70

# %%
try:
    num = int(input("숫자 입력 : ")) ** 2
    print(num)
except:
    print("숫자가 아닙니다.")

print("다음 실행문...")
# Out:
# 16
# 다음 실행문...

# %%
try:
    num = int(input("숫자 입력 : "))
    result = 10 / num
    print(result)

except ValueError:
    print("숫자를 입력하세요.")

except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
# Out:
# 숫자를 입력하세요.

# %%
try:
    print(10 / 2)
except:
    print("오류 발생")
finally:
    print("프로그램 종료")
# Out:
# 오류 발생
# 프로그램 종료

# %%
try:
    num = int(input("숫자 입력: "))
    result = 100 / num

except ValueError:
    print("숫자를 입력해야 합니다.")

except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")

else:
    print("계산 결과:", result)

finally:
    print("프로그램 종료")
# Out:
# 숫자를 입력해야 합니다.
# 프로그램 종료
