# %%
import my_math

print(my_math.add(1,2))

# print(add(1,2))
# Out:
# 3

# %%
from my_math import add 
print(add(2,4))
# Out:
# 6

# %%
from my_math import add as a # as=별칭
print(a(2,4))
# Out:
# 6

# %%
# greet 패키지 -> greet / ko.py - ko_greet(), en.py - en_greet()

import greet.ko # from greet import ko (as k)
import greet.en # from greet import en (as e)

greet.ko.ko_greet("홍길동")

#greet.en.en_greet("test")
# Out:
# '안녕하세요, 홍길동!'

# %%
greet.en.en_greet("test")
# Out:
# 'Hello, test!'
