# %%
def add(a, b):      #변수 -> 매개변수
    return a + b    #return 함수종료

add2=add

print(add)
print(add2)

print(add(1,3))
r1=add(10,20)
print(r1*100)

r2=add("abc","xyz")
print(r2)

def test():
    return

r3= print(test())
# Out:
# <function add at 0x0000021A86569800>
# <function add at 0x0000021A86569800>
# 4
# 3000
# abcxyz
# None

# %%
def test(a):        #지역변수 : 함수내에 있는 변수,함수 외에서는 변수로 인식X / a(매개변수),x 2개 생성
    x = 100+a
    print(x)

#print(a)
#print(x)
print(test(100))
# Out:
# 200
# None
