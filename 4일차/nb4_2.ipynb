# %%
s1 = "Python"
s2 = "Pytho"
s2= s2+"n"


print(s1 is s2) # false , 왜? s2가 가변객체(바뀔수 있어서)라서
print(s1 == s2) # True
# Out:
# False
# True

# %%
a = [1, 2, 3]
b = a

print(a == b) # True
print(a is b) # True

# 내장 함수 id()를 이용하면 동일 객체를 참조하는지 확인 가능
print(id(a))
print(id(b))
# Out:
# True
# True
# 2568859342016
# 2568859342016
